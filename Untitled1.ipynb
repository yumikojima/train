# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
from sklearn.ensemble import RandomForestClassifier

# %%
X = pd.read_csv("titanic_train.csv")
Y = X .pop("Survived")

# %%
X
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# 5              6       3                                   Moran, Mr. James
# 6              7       1                            McCarthy, Mr. Timothy J
# 7              8       3                     Palsson, Master. Gosta Leonard
# 8              9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9             10       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10            11       3                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
X.isnull().sum()
#欠損値の確認
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Ageは生存に関わるでしょ
#Ageの欠損値を中央値で補完
X["Age"].fillna(X.Age.mean(), inplace=True)

# %%
X
#Ageが補完されたことを確認
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# 5              6       3                                   Moran, Mr. James
# 6              7       1                            McCarthy, Mr. Timothy J
# 7              8       3                     Palsson, Master. Gosta Leonard
# 8              9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9             10       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10            11       3                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
#とりあえず、数字だけ出して見てみる
numeric_variables = list(X.dtypes[X.dtypes !="object"].index)
X[numeric_variables]
# Out:
#      PassengerId  Pclass        Age  SibSp  Parch      Fare
# 0              1       3  22.000000      1      0    7.2500
# 1              2       1  38.000000      1      0   71.2833
# 2              3       3  26.000000      0      0    7.9250
# 3              4       1  35.000000      1      0   53.1000
# 4              5       3  35.000000      0      0    8.0500
# 5              6       3  29.699118      0      0    8.4583
# 6              7       1  54.000000      0      0   51.8625
# 7              8       3   2.000000      3      1   21.0750
# 8              9       3  27.000000      0      2   11.1333
# 9             10       2  14.000000      1      0   30.0708
# 10            11       3   4.000000      1      1   16.7000
# 11            12       1  58.000000      0      0   26.5500
# 12            13       3  20.000000      0      0    8.0500
# 13            14       3  39.000000      1      5   31.2750
# 14            15       3  14.000000      0      0    7.8542
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_1 = RandomForestClassifier(random_state=0, n_estimators=100)
rfc_1.fit(X[numeric_variables], Y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# 特徴量の重要度を出力
importances = rfc_1.feature_importances_
importances
# Out:
# array([ 0.30229383,  0.08546709,  0.23897858,  0.05509058,  0.04020128,
#         0.27796864])

# %%
# 特徴量の重要度をグラフに出力
n_features = len(bc.feature_names)
plt.figure(figsize=(12, 8))
plt.barh(range(n_features), rfc_1.feature_importances_ , align='center')
plt.yticks(np.arange(n_features), bc.feature_names)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-f0ebd8b1ec5c> in <module>()
#       1 # 特徴量の重要度をグラフに出力
# ----> 2 n_features = len(bc.feature_names)
#       3 plt.figure(figsize=(12, 8))
#       4 plt.barh(range(n_features), rfc_1.feature_importances_ , align='center')
#       5 plt.yticks(np.arange(n_features), bc.feature_names)
#
# NameError: name 'bc' is not defined

# %%
tn = pd.read_csv("titanic_train.csv")
from sklearn.model_selection import train_test_split
X_1_train, X_1_test, y_1_train, y_1_test = train_test_split(tn.data, tn.target, test_size=0.3, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-e076e641e6bc> in <module>()
#       1 tn = pd.read_csv("titanic_train.csv")
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_1_train, X_1_test, y_1_train, y_1_test = train_test_split(tn.data, tn.target, test_size=0.3, random_state=0)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'data'
